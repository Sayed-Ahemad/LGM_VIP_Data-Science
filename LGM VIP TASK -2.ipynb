# %% [markdown]
# # Data Science Intern @LetsGrowMore VIP
# ## Task-2:-Image to Pencil Sketch with Python
# ## Author- Sayed Tufel Ahemad

# %% [markdown]
# ### Importing Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Loading Image

# %%
img = cv2.imread("sunflower.jpg")
img
# Out:
# array([[[201, 114,  64],
#         [201, 114,  64],
#         [201, 114,  64],
#         ...,
#         [ 58, 125,  88],
#         [ 56, 125,  88],
#         [ 56, 125,  88]],
#
#        [[201, 114,  64],
#         [201, 114,  64],
#         [201, 114,  64],
#         ...,
#         [ 56, 123,  86],
#         [ 54, 123,  86],
#         [ 53, 122,  85]],
#
#        [[201, 114,  64],
#         [201, 114,  64],
#         [201, 114,  64],
#         ...,
#         [ 55, 122,  85],
#         [ 55, 122,  85],
#         [ 55, 122,  85]],
#
#        ...,
#
#        [[ 49, 117,  86],
#         [ 50, 118,  87],
#         [ 53, 120,  93],
#         ...,
#         [ 25,  78,  58],
#         [ 16,  65,  45],
#         [  5,  54,  34]],
#
#        [[ 45, 115,  85],
#         [ 46, 116,  86],
#         [ 50, 117,  90],
#         ...,
#         [ 31,  83,  65],
#         [ 31,  81,  63],
#         [ 28,  78,  60]],
#
#        [[ 43, 114,  87],
#         [ 44, 115,  88],
#         [ 50, 117,  90],
#         ...,
#         [ 28,  80,  63],
#         [ 28,  77,  61],
#         [ 25,  74,  58]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray
# Out:
# array([[109, 109, 109, ..., 106, 106, 106],
#        [109, 109, 109, ..., 104, 104, 103],
#        [109, 109, 109, ..., 103, 103, 103],
#        ...,
#        [100, 101, 104, ...,  66,  53,  42],
#        [ 98,  99, 101, ...,  72,  70,  67],
#        [ 98,  99, 101, ...,  69,  67,  64]], dtype=uint8)

# %%
plt.imshow(img_gray)

# %%
img_invert = cv2.bitwise_not(img_gray)
img_invert
# Out:
# array([[146, 146, 146, ..., 149, 149, 149],
#        [146, 146, 146, ..., 151, 151, 152],
#        [146, 146, 146, ..., 152, 152, 152],
#        ...,
#        [155, 154, 151, ..., 189, 202, 213],
#        [157, 156, 154, ..., 183, 185, 188],
#        [157, 156, 154, ..., 186, 188, 191]], dtype=uint8)

# %%
plt.imshow(img_invert)

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21), sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[145, 145, 145, ..., 150, 150, 150],
#        [145, 145, 145, ..., 150, 150, 150],
#        [145, 145, 145, ..., 150, 150, 150],
#        ...,
#        [152, 152, 153, ..., 173, 176, 177],
#        [152, 153, 153, ..., 174, 177, 178],
#        [152, 153, 153, ..., 174, 177, 178]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# ### Final Sketch

# %%
final_img = dodgeV2(img_gray, img_smoothing)
plt.imshow(final_img)

# %%
cv2.imshow("Sketch", final_img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Thank You
